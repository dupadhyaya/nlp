# %%
#Remove Image Background

# %%
#!pip install rembg
#!pip install onnxruntime

# %%
from rembg import remove
from PIL import Image

# %%
input_path ='pm1.jpg'

# %%
output_path = 'pm2.png'

# %%
inp = Image.open(input_path)

# %%
output = remove(inp)

# %%
output.save(output_path)

# %%
Image.open('pm2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=614x614>
