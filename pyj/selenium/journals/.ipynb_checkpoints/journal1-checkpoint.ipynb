# %%
# journal analysis

# %% [markdown]
# # Links
# https://www.scimagojr.com/journalrank.php?out=xls
# /Users/du/dup/auData/research/sumitNarula/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
rdir1 = '/Users/du/dup/auData/journal/'
', '.join(os.listdir(rdir1))
# Out:
# 'CWTS Journal Indicators March 2024.xlsx, scimagojr2023.csv, .DS_Store, PredQ12StepsWard.pdf, Flow-diagram-of-journal-identification-selection-and-inclusion-in-each-study-group-a.png, Journal Evaluation Tool.pdf, 2021_Book_DataAndInformationInOnlineEnviarrastado.pdf, JOURNAL_CHANGE_MONTH_2024_12.xlsx, WOS DISCONTINUED JOURNALS DEC 2024.docx, thinkchecksubmit.org-Journals.pdf, countryRankings.xlsx'

# %% [markdown]
# # data in google drive
# https://docs.google.com/spreadsheets/d/1DmXhvNbYmRFhyF5vxPefP5QacJ3a7Se7-uzEt9nZb1w/edit?usp=sharing

# %%
fileName1 = 'scimagojr2023.csv'
print(rdir1+fileName1)
file1 = rdir1+fileName1
print(file1)
# Out:
# /Users/du/dup/auData/journal/scimagojr2023.csv
# /Users/du/dup/auData/journal/scimagojr2023.csv

# %%
data1 = pd.read_csv(file1, delimiter=';', on_bad_lines='skip')
data1.shape
# Out:
# (29165, 24)

# %%
data1.head(1)
# Out:
#    Rank  Sourceid                               Title     Type  \
# 0     1     28773  Ca-A Cancer Journal for Clinicians  journal
#
#                  Issn      SJR SJR Best Quartile  H index  Total Docs. (2023)  \
# 0  15424863, 00079235  106,094                Q1      211                  49
#
#    Total Docs. (3years)  ...  Ref. / Doc.  %Female  Overton SDG  \
# 0                   124  ...        98,86    43,95        2  35
#
#          Country            Region        Publisher   Coverage  \
# 0  United States  Northern America  Wiley-Blackwell  1950-2023
#
#                        Categories     Areas
# 0  Hematology (Q1); Oncology (Q1)  Medicine
#
# [1 rows x 24 columns]

# %%
data1.columns
# Out:
# Index(['Rank', 'Sourceid', 'Title', 'Type', 'Issn', 'SJR', 'SJR Best Quartile',
#        'H index', 'Total Docs. (2023)', 'Total Docs. (3years)', 'Total Refs.',
#        'Total Cites (3years)', 'Citable Docs. (3years)',
#        'Cites / Doc. (2years)', 'Ref. / Doc.', '%Female', 'Overton', 'SDG',
#        'Country', 'Region', 'Publisher', 'Coverage', 'Categories', 'Areas'],
#       dtype='object')

# %%
data1.head(2)
# Out:
#    Rank     Sourceid                                       Title     Type  \
# 0     1        28773          Ca-A Cancer Journal for Clinicians  journal
# 1     2  19300156903  Foundations and Trends in Machine Learning  journal
#
#                  Issn      SJR SJR Best Quartile  H index  Total Docs. (2023)  \
# 0  15424863, 00079235  106,094                Q1      211                  49
# 1  19358245, 19358237   37,044                Q1       39                   3
#
#    Total Docs. (3years)  ...  Ref. / Doc.  %Female  Overton SDG  \
# 0                   124  ...        98,86    43,95        2  35
# 1                    13  ...       299,00    27,78        0   0
#
#          Country            Region           Publisher   Coverage  \
# 0  United States  Northern America     Wiley-Blackwell  1950-2023
# 1  United States  Northern America  Now Publishers Inc  2008-2023
#
#                                           Categories             Areas
# ...

# %%
mask11 = data1['Title'].str.contains('Content')
mask12 = data1['Title'].str.contains('Community')
mask13 = data1['Title'].str.contains('Communication')

# %%
data1[mask11 & mask12 & mask13].head()
# Out:
#         Rank     Sourceid                                            Title  \
# 16769  16770  21100868095  Journal of Content, Community and Communication
#
#           Type                Issn    SJR SJR Best Quartile  H index  \
# 16769  journal  23957514, 24569011  0,269                Q2       14
#
#        Total Docs. (2023)  Total Docs. (3years)  ...  Ref. / Doc.  %Female  \
# 16769                  28                   144  ...        71,18    40,54
#
#        Overton SDG Country          Region         Publisher   Coverage  \
# 16769        0   5   India  Asiatic Region  Amity University  2015-2023
#
#                Categories            Areas
# 16769  Communication (Q2)  Social Sciences
#
# [1 rows x 24 columns]

# %%
mask14 = data1['Publisher'].str.contains('Amity')
mask14.sum()
# Out:
# 1

# %%
data1.dropna()[data1.dropna()['Publisher'].str.contains('Amity')]
#df.dropna()[df.dropna()['Label'].str.contains('target')]
# Out:
#         Rank     Sourceid                                            Title  \
# 16769  16770  21100868095  Journal of Content, Community and Communication
#
#           Type                Issn    SJR SJR Best Quartile  H index  \
# 16769  journal  23957514, 24569011  0,269                Q2       14
#
#        Total Docs. (2023)  Total Docs. (3years)  ...  Ref. / Doc.  %Female  \
# 16769                  28                   144  ...        71,18    40,54
#
#        Overton SDG Country          Region         Publisher   Coverage  \
# 16769        0   5   India  Asiatic Region  Amity University  2015-2023
#
#                Categories            Areas
# 16769  Communication (Q2)  Social Sciences
#
# [1 rows x 24 columns]

# %%
data1.dropna()[data1.dropna()['Country'].str.contains('India')]
# Out:
#         Rank     Sourceid                                              Title  \
# 557      558  21100922754                    Higher Education for the Future
# 1621    1622  12000154405                           Hepatology International
# 2819    2820        18069                                       Neurosurgery
# 3288    3289  21100370010                              Endoscopic Ultrasound
# 4058    4059  21101055964        Asian Journal of Social Health and Behavior
# ...      ...          ...                                                ...
# 27794  27795        27767        Journal of Forensic Medicine and Toxicology
# 27795  27796  21100892239  Journal of Indian Council of Philosophical Res...
# 27802  27803        29590                   Journal of Spacecraft Technology
# 27996  27997       100922                              Asian Textile Journal
# 28389  28390  21100902868                                  Punjab Geographer
#
# ...

# %%
#SJR Country Rankings

# %%
fileName2 ='countryRankings.xlsx'

# %%
data2 = pd.read_excel(rdir1 + fileName2)

# %%
data2.head()
# Out:
#    Rank         Country            Region  Documents  Citable documents  \
# 0     1   United States  Northern America   16047770           13969135
# 1     2           China    Asiatic Region   10372322           10180089
# 2     3  United Kingdom    Western Europe    4778980            3984194
# 3     4         Germany    Western Europe    4104599            3741033
# 4     5           Japan    Asiatic Region    3482279            3308467
#
#    Citations  Self-citations  Citations per document  H index
# 0  515339352       211154763                   32.11     3051
# 1  145875947        86501833                   14.06     1333
# 2  142963939        29272921                   29.92     1928
# 3  110076588        24142498                   26.82     1690
# 4   70350390        16354163                   20.20     1301

# %% [markdown]
# #CWTS Indicators
# https://www.journalindicators.com/downloads

# %%
fileName3 ='CWTS Journal Indicators March 2024.xlsx'

# %%
data3 = pd.read_excel(rdir1 + fileName3)
data3.shape
# Out:
# (530218, 15)

# %%
data3.head()
# Out:
#                                         Source title            Source type  \
# 0  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
# 1  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
# 2  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
# 3  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
# 4  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
#
#   Print ISSN Electronic ISSN ASJC field IDs  Year  Citing source    P  \
# 0          -               -           2200  2001              0  208
# 1          -               -           2200  2002              0  208
# 2          -               -           2200  2003              0  292
# 3          -               -           2200  2004              0   84
# 4          -               -           2200  2005              0   84
#
#         IPP  IPP (lower bound)  IPP (upper bound)      SNIP  \
# ...

# %%
data3.columns
# Out:
# Index(['Source title', 'Source type', 'Print ISSN', 'Electronic ISSN',
#        'ASJC field IDs', 'Year', 'Citing source', 'P', 'IPP',
#        'IPP (lower bound)', 'IPP (upper bound)', 'SNIP', 'SNIP (lower bound)',
#        'SNIP (upper bound)', '% self cit'],
#       dtype='object')

# %%
data3[data3['Source title'].str.contains('Content|Communication')].head()
# Out:
#                                         Source title            Source type  \
# 0  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
# 1  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
# 2  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
# 3  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
# 4  2000 IEEE Wireless Communications and Networki...  Conference Proceeding
#
#   Print ISSN Electronic ISSN ASJC field IDs  Year  Citing source    P  \
# 0          -               -           2200  2001              0  208
# 1          -               -           2200  2002              0  208
# 2          -               -           2200  2003              0  292
# 3          -               -           2200  2004              0   84
# 4          -               -           2200  2005              0   84
#
#         IPP  IPP (lower bound)  IPP (upper bound)      SNIP  \
# ...

# %%
mask1 = data3['Source title'].str.contains('Content')
mask2 = data3['Source title'].str.contains('Community')
mask3 = data3['Source title'].str.contains('Communication')

# %%
data3[mask1 & mask2 & mask3].head()
# Out:
#                                            Source title Source type  \
# 273829  Journal of Content, Community and Communication     Journal
# 273830  Journal of Content, Community and Communication     Journal
# 273831  Journal of Content, Community and Communication     Journal
# 273832  Journal of Content, Community and Communication     Journal
# 273833  Journal of Content, Community and Communication     Journal
#
#        Print ISSN Electronic ISSN ASJC field IDs  Year  Citing source   P  \
# 273829  2395-7514       2456-9011           3315  2016              0  10
# 273830  2395-7514       2456-9011           3315  2017              0  26
# 273831  2395-7514       2456-9011           3315  2018              1  50
# 273832  2395-7514       2456-9011           3315  2019              1  59
# 273833  2395-7514       2456-9011           3315  2020              1  84
#
#              IPP  IPP (lower bound)  IPP (upper bound)      SNIP  \
# ...

# %%
data3[mask1 & mask2 & mask3].iloc[:,[0,5,7,8,11,14]]
# Out:
#                                            Source title  Year    P       IPP  \
# 273829  Journal of Content, Community and Communication  2016   10  0.000000
# 273830  Journal of Content, Community and Communication  2017   26  0.076923
# 273831  Journal of Content, Community and Communication  2018   50  0.080000
# 273832  Journal of Content, Community and Communication  2019   59  0.050847
# 273833  Journal of Content, Community and Communication  2020   84  0.678571
# 273834  Journal of Content, Community and Communication  2021  109  0.513761
# 273835  Journal of Content, Community and Communication  2022  147  1.299320
# 273836  Journal of Content, Community and Communication  2023  140  1.328571
#
#             SNIP  % self cit
# 273829  0.000000    0.000000
# 273830  0.226211    0.000000
# 273831  0.205617    0.000000
# 273832  0.110082    0.000000
# 273833  0.563623    0.964912
# 273834  0.361540    0.464286
# 273835  0.435642    0.397906
# 273836  0.504272    0.107527
