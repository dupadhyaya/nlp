# %%
# sticky Land

# %%
#!pip install stickyland
#https://github.com/xiaohk/stickyland?utm_content=buffer2b852&utm_medium=social&utm_source=linkedin.com&utm_campaign=short+posts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 10.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 8.6.0
#     Uninstalling jupyter_client-8.6.0:
#       Successfully uninstalled jupyter_client-8.6.0
#   Attempting uninstall: notebook
#     Found existing installation: notebook 7.2.2
#     Uninstalling notebook-7.2.2:
#       Successfully uninstalled notebook-7.2.2
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.3.4
#     Uninstalling jupyterlab-4.3.4:
#       Successfully uninstalled jupyterlab-4.3.4
# ...
