# %% [markdown]
# # Examples from my own site, using html egs created by self
# -

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import os

# %%
os.listdir('../htmleg/')
# Out:
# ['divtags.html', 'duprofile1.html', 'ducv1.html', '.ipynb_checkpoints']

# %%
# Load html files from github
prfe = 'https://htmlpreview.github.io/?'
mid = 'https://github.com/dupadhyaya/nlp/blob/main/pyj/htmleg/'
divtags = 'divtags.html'
ducv1 = 'duc1.html'
duprofile1 = 'duprofile1.html'

# %%
# URL on the Github where the csv files are stored
github_url = 'https://github.com/dupadhyaya/nlp/tree/main/pyj/htmleg/'
result = requests.get(github_url)
soup = BeautifulSoup(result.text, 'html.parser')
htmlfiles = soup.find_all(title=re.compile("\.html$"))
len(htmlfiles)
# Out:
# 6

# %%
filename = [ ]
for i in htmlfiles:
        filename.append(i.extract().get_text())
print(filename)
# Out:
# ['divtags.html', 'divtags.html', 'ducv1.html', 'ducv1.html', 'duprofile1.html', 'duprofile1.html']

# %%
udiv1 = mid + divtags
udiv1
udiv1 ='https://htmlpreview.github.io/?https://github.com/dupadhyaya/nlp/blob/main/pyj/htmlegs/divtags.html'

# %%
result = requests.get(udiv1).text
print(result)
#doc = BeautifulSoup(result, 'html.parser')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<meta charset="utf-8">
# 	<title>GitHub &amp; BitBucket HTML Preview</title>
# 	<style>
# 	body {
# 		font: 12px 'Helvetica Neue', Helvetica, Arial, freesans, clean, sans-serif;
# 		color: #333;
# 	}
# 	h1 {
# 		font-size: 20px;
# 	}
# 	a {
# 		color: #666;
# 	}
# 	#previewform {
# 		display: none;
# 		padding: 20px;
# 		text-align: center;
# 	}
# 	strong {
# 		color: #333;
# 		background-color: #FAFFA6;
# 		padding: 0.1em;
# 	}
# 	#footer {
# 		margin: 20px 0;
# 		font-size: 10px;
# 		color: #666;
# 	}
# 	</style>
# </head>
# <body>
# 	<form id="previewform" onsubmit="location.href='/?'+this.file.value;return false">
# 		<h1>GitHub &amp; BitBucket HTML Preview</h1>
# 		<p>
# 			Enter URL of the HTML file to preview:
# 			<input type="url" id="file" value="" placeholder="e.g. https://github.com/user/repo/blob/master/index.html" size="60" autofocus>
# 			<input type="submit" value="Preview">
# 		</p>
# ...

# %%
doc
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-a11y-link-underlines="true" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...
